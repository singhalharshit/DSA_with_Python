# %%
bound_by = '[[]]'
len(bound_by)
bound_by[0:(len(bound_by)//2)]
# Out:
# '[['

# %%
str = "hello"
if str.islower() == True:
    print(str.title())
# Out:
# Hello

# %%
if __name__ == '__main__':
    N = int(input())
    n=N
    l=[]
    while n!=0:
        ask= input().split(' ')
        if 'append' in ask: 
            l.append()
        n-=1
# Out:
# append 5
